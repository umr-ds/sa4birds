# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch==2.2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: torchvision==0.17.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: torchaudio==2.2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: timm==1.0.22 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.0.22)
# Requirement already satisfied: torchmetrics==1.2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: scikit-learn==1.3.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: datasets in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: hydra-core in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: transformers==4.38.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (4.38.0)
# Requirement already satisfied: soundfile in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: librosa in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.10.1)
# Requirement already satisfied: numpy<2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.26.4)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in ./.venv/lib/python3.12/site-packages (from torch==2.2.0->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from torchvision==0.17.0->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.venv/lib/python3.12/site-packages (from torchvision==0.17.0->-r requirements.txt (line 2)) (12.1.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from timm==1.0.22->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: huggingface_hub in ./.venv/lib/python3.12/site-packages (from timm==1.0.22->-r requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.12/site-packages (from timm==1.0.22->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in ./.venv/lib/python3.12/site-packages (from torchmetrics==1.2.0->-r requirements.txt (line 5)) (0.15.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (2.3.3)
# Requirement already satisfied: tqdm>=4.66.3 in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from datasets->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers==4.38.0->-r requirements.txt (line 9)) (2025.11.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.12/site-packages (from transformers==4.38.0->-r requirements.txt (line 9)) (0.15.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from huggingface_hub->timm==1.0.22->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in ./.venv/lib/python3.12/site-packages (from hydra-core->-r requirements.txt (line 8)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./.venv/lib/python3.12/site-packages (from hydra-core->-r requirements.txt (line 8)) (4.9.3)
# Requirement already satisfied: cffi>=1.0 in ./.venv/lib/python3.12/site-packages (from soundfile->-r requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: decorator>=4.3.0 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (0.63.1)
# Requirement already satisfied: pooch>=1.0 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: lazy-loader>=0.1 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in ./.venv/lib/python3.12/site-packages (from librosa->-r requirements.txt (line 11)) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 10)) (2.23)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0->-r requirements.txt (line 5)) (80.9.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.12/site-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 11)) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 11)) (4.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->torchvision==0.17.0->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->torchvision==0.17.0->-r requirements.txt (line 2)) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->torchvision==0.17.0->-r requirements.txt (line 2)) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch==2.2.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->datasets->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->datasets->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->datasets->-r requirements.txt (line 7)) (2025.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->torch==2.2.0->-r requirements.txt (line 1)) (1.3.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch

from utils.event_decoder import EventDecoding
from models.dsa import DSA
from utils.transform import ValTransform
from checkpoints import DT, MT, LT
import librosa
import soundfile as sf

SAMPLE_RATE = 32000
FILEPATH = "XC973025.mp3"

# %%
# !wget -O XC973025.mp3 https://xeno-canto.org/973025/download
# Out:
# --2026-02-11 10:27:35--  https://xeno-canto.org/973025/download
# Resolving xeno-canto.org (xeno-canto.org)... 145.136.250.151
# Connecting to xeno-canto.org (xeno-canto.org)|145.136.250.151|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [audio/mpeg]
# Saving to: ‘XC973025.mp3’
#
# XC973025.mp3            [ <=>                ]   1.25M  --.-KB/s    in 0.1s
#
# 2026-02-11 10:27:35 (10.7 MB/s) - ‘XC973025.mp3’ saved [1311882]

# %%
def build_model(cfg):
    if cfg.network.classifier == "DSA":
        base_model = DSA(cfg)
    else:
        raise NotImplementedError

    base_model.to(cfg.train.device)
    return base_model

def load_model(checkpoint):
    state_dict = torch.load(f"{checkpoint}/models/model.pth")
    state_dict, config = state_dict['state_dict'], state_dict['config']
    model = build_model(config)
    model.load_state_dict(state_dict)
    model.eval()
    return model, config

# %%
# down_task = "HSN"
# change it if you want to use a different model
ckpt = LT.get('ALL', [])[0]

model, cfg = load_model(ckpt)
transform = ValTransform(
        config=cfg,
        train=False,
        event_decoder=EventDecoding(extracted_interval=cfg.event_decoder.val.extracted_interval),
)
label_map = { v:k for k,v in cfg.train.label_map.items()}

file_info = sf.info(FILEPATH)
sr = file_info.samplerate
audio, sr = sf.read(FILEPATH, start=0, stop=7*sr)


if audio.ndim != 1:
    audio = audio.swapaxes(1, 0)
    audio = librosa.to_mono(audio)
if sr != SAMPLE_RATE:
    audio = librosa.resample(audio, orig_sr=sr, target_sr=SAMPLE_RATE)
    sr = SAMPLE_RATE

fbank_features = transform.get_spectrogram(torch.tensor(audio).unsqueeze(0).unsqueeze(0).float())
fbank_features = transform.pad(fbank_features)
fbank_features = (fbank_features - cfg.frontend.mean) / ( cfg.frontend.std * 2)

with torch.no_grad():
    preds = model(fbank_features.to(cfg.train.device))
    top1 = preds.topk(1)
    print(f"{label_map[int(top1.indices[0])]}: {top1.values[0][0]}")
# Out:
# redkit1: 0.957703173160553
